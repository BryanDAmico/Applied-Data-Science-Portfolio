# %%
#Importing required packages
import nltk
import re
import pandas as pd
import numpy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Import the data frame
mtg = pd.read_csv("MTG_Cards")
mtg = mtg.drop(columns = "Unnamed: 0")
mtg
# Out:
#                     Name                                               Text  \
# 0                +2 Mace  Equipped creature gets +2/+2 Equip {3} {3}: At...
# 1        Abbey Gargoyles                         Flying protection from red
# 2          Abbey Griffin                                   Flying vigilance
# 3           Abbey Matron  {W} {T}: Abbey Matron gets +0/+3 until end of ...
# 4               Abeyance  Until end of turn target player can t cast ins...
# ...                  ...                                                ...
# 12039      Wolf's Quarry  Create three 1/1 green Boar creature tokens wi...
# 12040        Wolf Strike  Target creature you control gets +2/+0 until e...
# 12041     Wolverine Pack  Rampage 2 Whenever this creature becomes block...
# 12042   Wolverine Riders  At the beginning of each upkeep create a 1/1 g...
# 12043  Woodborn Behemoth  As long as you control eight or more lands Woo...
#
#                                                   Flavor  Color          Cost  \
# 0      The weight of this magic weapon falls heavy on...  White        {1}{W}
# 1      Though Serra has not been seen for twenty year...  White  {2}{W}{W}{W}
# 2      The darkness crawls with vampires and ghouls b...  White        {3}{W}
# 3      The Matrons are kindly souls but don t ask one...  White        {2}{W}
# 4      I m too modest a wizard to reveal the full ext...  White        {1}{W}
# ...                                                  ...    ...           ...
# 12039  The monster was gaining on them Twice it had f...  Green     {4}{G}{G}
# 12040  Tovolar s howlpack had scattered but the Dire ...  Green        {2}{G}
# 12041  Give them great meals of beef and iron and ste...  Green     {2}{G}{G}
# 12042     We ll break their lines The rest of you follow  Green     {4}{G}{G}
# 12043  It carries the hopes of Zendikar s embattled w...  Green     {3}{G}{G}
#
#                           Type    Rarity
# 0         Artifact — Equipment    common
# 1          Creature — Gargoyle  uncommon
# 2           Creature — Griffin    common
# 3      Creature — Human Cleric    common
# 4                      Instant      rare
# ...                        ...       ...
# 12039                  Sorcery    common
# 12040                  Instant    common
# 12041     Creature — Wolverine  uncommon
# 12042   Creature — Elf Warrior      rare
# 12043     Creature — Elemental  uncommon
#
# [12044 rows x 7 columns]

# %%
all_flavor = mtg["Flavor"].tolist()
all_flavor[:5]
# Out:
# ['The weight of this magic weapon falls heavy on the wicked',
#  'Though Serra has not been seen for twenty years her gargoyles still watch over our city and punish the guilty —Gulsen abbey matron',
#  'The darkness crawls with vampires and ghouls but we are not without allies —Mikaeus the Lunarch',
#  'The Matrons are kindly souls but don t ask one for an ale —Halina Dwarven Trader',
#  'I m too modest a wizard to reveal the full extent of my abilities —Ertai wizard adept']

# %%
all_flavor_compound_scores = []

#Iterating over the list of comments, priting each comment along with its sentiment polarity scores, while appending 
#the compound scores to the list
for text in all_flavor:
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    all_flavor_compound_scores.append(score["compound"])

# %%
#Adding the VADER compound scores as a new column in the AI data frame
mtg["VADER_Compound"] = all_flavor_compound_scores

# %%
mtg
# Out:
#                     Name                                               Text  \
# 0                +2 Mace  Equipped creature gets +2/+2 Equip {3} {3}: At...
# 1        Abbey Gargoyles                         Flying protection from red
# 2          Abbey Griffin                                   Flying vigilance
# 3           Abbey Matron  {W} {T}: Abbey Matron gets +0/+3 until end of ...
# 4               Abeyance  Until end of turn target player can t cast ins...
# ...                  ...                                                ...
# 12039      Wolf's Quarry  Create three 1/1 green Boar creature tokens wi...
# 12040        Wolf Strike  Target creature you control gets +2/+0 until e...
# 12041     Wolverine Pack  Rampage 2 Whenever this creature becomes block...
# 12042   Wolverine Riders  At the beginning of each upkeep create a 1/1 g...
# 12043  Woodborn Behemoth  As long as you control eight or more lands Woo...
#
#                                                   Flavor  Color          Cost  \
# 0      The weight of this magic weapon falls heavy on...  White        {1}{W}
# 1      Though Serra has not been seen for twenty year...  White  {2}{W}{W}{W}
# 2      The darkness crawls with vampires and ghouls b...  White        {3}{W}
# 3      The Matrons are kindly souls but don t ask one...  White        {2}{W}
# 4      I m too modest a wizard to reveal the full ext...  White        {1}{W}
# ...                                                  ...    ...           ...
# 12039  The monster was gaining on them Twice it had f...  Green     {4}{G}{G}
# 12040  Tovolar s howlpack had scattered but the Dire ...  Green        {2}{G}
# 12041  Give them great meals of beef and iron and ste...  Green     {2}{G}{G}
# 12042     We ll break their lines The rest of you follow  Green     {4}{G}{G}
# 12043  It carries the hopes of Zendikar s embattled w...  Green     {3}{G}{G}
#
#                           Type    Rarity  VADER_Compound
# 0         Artifact — Equipment    common         -0.6808
# 1          Creature — Gargoyle  uncommon         -0.7351
# 2           Creature — Griffin    common         -0.1280
# 3      Creature — Human Cleric    common          0.2732
# 4                      Instant      rare          0.2500
# ...                        ...       ...             ...
# 12039                  Sorcery    common          0.2732
# 12040                  Instant    common         -0.6486
# 12041     Creature — Wolverine  uncommon          0.4215
# 12042   Creature — Elf Warrior      rare          0.0000
# 12043     Creature — Elemental  uncommon          0.4215
#
# [12044 rows x 8 columns]

# %%
#Average sentiment score of all flavor texts
mtg["VADER_Compound"].mean()
# Out:
# -0.014374036864828962

# %%
mtg["VADER_Compound"].median()
# Out:
# 0.0

# %%
mtg["VADER_Compound"].max()
# Out:
# 0.963

# %%
mtg[mtg["VADER_Compound"] == mtg["VADER_Compound"].max()]
# Out:
#                Name                                               Text  \
# 10529  Growth Spurt  Roll a six sided die Target creature gets +X/+...
#
#                                                   Flavor  Color    Cost  \
# 10529  MORE TO LOVE: Friendly nature loving Bunyonesq...  Green  {1}{G}
#
#           Type  Rarity  VADER_Compound  Clean_VADER
# 10529  Instant  common           0.963       0.9499

# %%
mtg["VADER_Compound"].min()
# Out:
# -0.9792

# %%
mtg[mtg["VADER_Compound"] == mtg["VADER_Compound"].min()]
# Out:
#                 Name                                               Text  \
# 6708  Restless Bones  {3}{B} {T}: Target creature gains swampwalk un...
#
#                                                  Flavor  Color    Cost  \
# 6708  We mourn our dead We shroud our dead We bury o...  Black  {2}{B}
#
#                      Type  Rarity  VADER_Compound  Clean_VADER
# 6708  Creature — Skeleton  common         -0.9792      -0.9792

# %%
scores_DF = pd.DataFrame(mtg.groupby("Color")["VADER_Compound"].mean())
scores_DF = scores_DF.rename(columns = {"VADER_Compound":"Mean Score"})
scores_DF
# Out:
#        Mean Score
# Color
# Black   -0.122138
# Blue     0.020258
# Green    0.029867
# Red     -0.048348
# White    0.048089

# %%
medians_DF = pd.DataFrame(mtg.groupby("Color")["VADER_Compound"].median())
scores_DF = scores_DF.merge(medians_DF, on = "Color")
scores_DF = scores_DF.rename(columns = {"VADER_Compound": "Median Score"})
scores_DF
# Out:
#        Mean Score  Median Score
# Color
# Black   -0.122138       -0.0258
# Blue     0.020258        0.0000
# Green    0.029867        0.0000
# Red     -0.048348        0.0000
# White    0.048089        0.0000

# %%
max_df = pd.DataFrame(mtg.groupby("Color")["VADER_Compound"].max())
scores_DF = scores_DF.merge(max_df, on = "Color")
scores_DF = scores_DF.rename(columns = {"VADER_Compound": "Max Score"})
scores_DF
# Out:
#        Mean Score  Median Score  Max Score
# Color
# Black   -0.122138       -0.0258     0.9581
# Blue     0.020258        0.0000     0.9545
# Green    0.029867        0.0000     0.9630
# Red     -0.048348        0.0000     0.9360
# White    0.048089        0.0000     0.9423

# %%
min_df = pd.DataFrame(mtg.groupby("Color")["VADER_Compound"].min())
scores_DF = scores_DF.merge(min_df, on = "Color")
scores_DF = scores_DF.rename(columns = {"VADER_Compound": "Min Score"})
scores_DF
# Out:
#        Mean Score  Median Score  Max Score  Min Score
# Color
# Black   -0.122138       -0.0258     0.9581    -0.9792
# Blue     0.020258        0.0000     0.9545    -0.9349
# Green    0.029867        0.0000     0.9630    -0.9253
# Red     -0.048348        0.0000     0.9360    -0.9360
# White    0.048089        0.0000     0.9423    -0.9588

# %%
mtg[(mtg["Color"] == "Black") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Black"]["VADER_Compound"].max())]
# Out:
#                  Name                                               Text  \
# 5527  Dinosaur Hunter  Whenever Dinosaur Hunter deals damage to a Din...
#
#                                                  Flavor  Color    Cost  \
# 5527  Aye the foul beast chomped me but I got away Y...  Black  {1}{B}
#
#                          Type  Rarity  VADER_Compound  Clean_VADER
# 5527  Creature — Human Pirate  common          0.9581       0.9493

# %%
mtg[(mtg["Color"] == "Black") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Black"]["VADER_Compound"].min())]
# Out:
#                 Name                                               Text  \
# 6708  Restless Bones  {3}{B} {T}: Target creature gains swampwalk un...
#
#                                                  Flavor  Color    Cost  \
# 6708  We mourn our dead We shroud our dead We bury o...  Black  {2}{B}
#
#                      Type  Rarity  VADER_Compound  Clean_VADER
# 6708  Creature — Skeleton  common         -0.9792      -0.9792

# %%
mtg[(mtg["Color"] == "Blue") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Blue"]["VADER_Compound"].max())]
# Out:
#                   Name                                               Text  \
# 9167  Soaring Show-Off  Flying When Soaring Show Off enters the battle...
#
#                                                  Flavor Color    Cost  \
# 9167  Some spectators love an underdog but others ar...  Blue  {2}{U}
#
#                          Type  Rarity  VADER_Compound  Clean_VADER
# 9167  Creature — Bird Warrior  common          0.9545       0.9545

# %%
mtg[(mtg["Color"] == "Blue") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Blue"]["VADER_Compound"].min())]
# Out:
#                              Name  \
# 8308  Ioreth of the Healing House
#
#                                                    Text  \
# 8308  {T}: Untap another target permanent {T}: Untap...
#
#                                                  Flavor Color    Cost  \
# 8308  I have been too busy with this and that to hee...  Blue  {2}{U}
#
#                                    Type    Rarity  VADER_Compound  Clean_VADER
# 8308  Legendary Creature — Human Cleric  uncommon         -0.9349      -0.9349

# %%
mtg[(mtg["Color"] == "Green") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Green"]["VADER_Compound"].max())]
# Out:
#                Name                                               Text  \
# 10529  Growth Spurt  Roll a six sided die Target creature gets +X/+...
#
#                                                   Flavor  Color    Cost  \
# 10529  MORE TO LOVE: Friendly nature loving Bunyonesq...  Green  {1}{G}
#
#           Type  Rarity  VADER_Compound  Clean_VADER
# 10529  Instant  common           0.963       0.9499

# %%
mtg[(mtg["Color"] == "Green") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Green"]["VADER_Compound"].min())]
# Out:
#                       Name                                               Text  \
# 11491  Silhana Ledgewalker  Hexproof This creature can t be the target of ...
#
#                                                   Flavor  Color    Cost  \
# 11491  Street folk call them spire mice but behind th...  Green  {1}{G}
#
#                        Type  Rarity  VADER_Compound  Clean_VADER
# 11491  Creature — Elf Rogue  common         -0.9253      -0.9253

# %%
mtg[(mtg["Color"] == "Red") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Red"]["VADER_Compound"].max())]
# Out:
#                Name                                               Text  \
# 3415  Goblin Bookie  {R} {T}: Reflip any coin or reroll any die Act...
#
#                                                  Flavor Color Cost  \
# 3415  Glok loved bets He d sit in the bar all night ...   Red  {R}
#
#                    Type  Rarity  VADER_Compound  Clean_VADER
# 3415  Creature — Goblin  common           0.936        0.936

# %%
mtg[(mtg["Color"] == "Red") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "Red"]["VADER_Compound"].min())]
# Out:
#                   Name                                           Text  \
# 3819  Lambholt Harrier  {3}{R}: Target creature can t block this turn
#
#                                                  Flavor Color    Cost  \
# 3819  This Tovolar is no brainless brute He sends hi...   Red  {1}{R}
#
#                  Type  Rarity  VADER_Compound  Clean_VADER
# 3819  Creature — Wolf  common          -0.936      -0.9201

# %%
mtg[(mtg["Color"] == "White") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "White"]["VADER_Compound"].max())]
# Out:
#                      Name                                               Text  \
# 1372  Liu Bei Lord of Shu  Horsemanship This creature can t be blocked ex...
#
#                                                  Flavor  Color       Cost  \
# 1372  Only wisdom and virtue can truly win men s dev...  White  {3}{W}{W}
#
#                                     Type Rarity  VADER_Compound  Clean_VADER
# 1372  Legendary Creature — Human Soldier   rare          0.9423       0.9423

# %%
mtg[(mtg["Color"] == "White") & (mtg["VADER_Compound"] == mtg[mtg["Color"] == "White"]["VADER_Compound"].min())]
# Out:
#                  Name                                               Text  \
# 115  Angel of Renewal  Flying When Angel of Renewal enters the battle...
#
#                                                 Flavor  Color    Cost  \
# 115  No more fear No more failure No more death No ...  White  {5}{W}
#
#                       Type    Rarity  VADER_Compound  Clean_VADER
# 115  Creature — Angel Ally  uncommon         -0.9588      -0.9154
